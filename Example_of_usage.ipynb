# %% [markdown]
# <a href="https://colab.research.google.com/github/panos108/ANN_for_MPC_pretraining/blob/master/Example_of_usage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
